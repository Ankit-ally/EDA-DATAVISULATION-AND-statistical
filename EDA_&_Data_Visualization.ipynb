# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankit-ally/EDA-DATAVISULATION-AND-statistical/blob/main/EDA_%26_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load csv file

# %%
url = "https://docs.google.com/spreadsheets/d/1Pxr1mT-HHAKb6TaSqjSwt7n24Z8ofvNnIe3dqKov4gs/export?format=csv&gid=1665016267"
df = pd.read_csv(url)

df.head()
# Out:
#    delivery_id delivery_partner      package_type vehicle_type delivery_mode  \
# 0       250.99        delhivery  automobile parts         bike      same day
# 1       250.99       xpressbees         cosmetics       ev van       express
# 2       250.99        shadowfax         groceries        truck       two day
# 3       250.99              dhl       electronics       ev van      same day
# 4       250.99              dhl          clothing          van       two day
#
#     region weather_condition  distance_km  package_weight_kg  \
# 0     west             clear        297.0              46.96
# 1  central              cold         89.6              47.39
# 2     east             rainy        273.5              26.89
# 3     east              cold        269.7              12.69
# 4    north             foggy        256.7              37.02
#
#   delivery_time_hours expected_time_hours delayed delivery_status  \
# ...

# %% [markdown]
# **bold text**## Data Understanding

# %% [markdown]
# ### Viewing Sample data

# %%
#Top 5 rows
df.head()
# Out:
#    delivery_id delivery_partner      package_type vehicle_type delivery_mode  \
# 0       250.99        delhivery  automobile parts         bike      same day
# 1       250.99       xpressbees         cosmetics       ev van       express
# 2       250.99        shadowfax         groceries        truck       two day
# 3       250.99              dhl       electronics       ev van      same day
# 4       250.99              dhl          clothing          van       two day
#
#     region weather_condition  distance_km  package_weight_kg  \
# 0     west             clear        297.0              46.96
# 1  central              cold         89.6              47.39
# 2     east             rainy        273.5              26.89
# 3     east              cold        269.7              12.69
# 4    north             foggy        256.7              37.02
#
#   delivery_time_hours expected_time_hours delayed delivery_status  \
# ...

# %%
#Bottom 5 rows
df.tail()
# Out:
#        delivery_id delivery_partner      package_type vehicle_type  \
# 24995     24750.01              dhl         furniture      scooter
# 24996     24750.01     ecom express  automobile parts       ev van
# 24997     24750.01            ekart          clothing      scooter
# 24998     24750.01        shadowfax         documents       ev van
# 24999     24750.01        blue dart          pharmacy      ev bike
#
#       delivery_mode   region weather_condition  distance_km  \
# 24995       two day     east             foggy         80.7
# 24996      standard     west             clear        172.9
# 24997      same day     east             rainy        168.4
# 24998      standard     west            stormy         37.2
# 24999       two day  central             rainy        279.3
#
#        package_weight_kg delivery_time_hours expected_time_hours delayed  \
# 24995               3.65  1970-01-01 0:00:00  1970-01-01 0:00:00      no
# ...

# %%
#Random 5 rows
df.sample(5)
# Out:
#        delivery_id delivery_partner package_type vehicle_type delivery_mode  \
# 22611      22612.0        shadowfax    groceries         bike       two day
# 15192      15193.0        shadowfax     clothing          van       two day
# 21374      21375.0       xpressbees     pharmacy         bike      same day
# 20882      20883.0            fedex    furniture      ev bike      standard
# 4701        4702.0        delhivery     pharmacy        truck       express
#
#         region weather_condition  distance_km  package_weight_kg  \
# 22611     east            stormy        204.5              17.63
# 15192    north             rainy          8.1              45.40
# 21374     east             clear        258.4               6.59
# 20882     east             clear        235.0              25.90
# 4701   central            stormy         17.3              30.38
#
#       delivery_time_hours expected_time_hours delayed delivery_status  \
# ...

# %% [markdown]
# ### Shape and column info

# %%
#Number of rows and columns
df.shape
# Out:
# (25000, 15)

# %%
#Column names
df.columns
# Out:
# Index(['delivery_id', 'delivery_partner', 'package_type', 'vehicle_type',
#        'delivery_mode', 'region', 'weather_condition', 'distance_km',
#        'package_weight_kg', 'delivery_time_hours', 'expected_time_hours',
#        'delayed', 'delivery_status', 'delivery_rating', 'delivery_cost'],
#       dtype='object')

# %%
#Data types
"""view the above dataframe and compare the datatype and value. sometime int and float may triggered as Object"""
df.dtypes
# Out:
# delivery_id            float64
# delivery_partner        object
# package_type            object
# vehicle_type            object
# delivery_mode           object
# region                  object
# weather_condition       object
# distance_km            float64
# package_weight_kg      float64
# delivery_time_hours     object
# expected_time_hours     object
# delayed                 object
# delivery_status         object
# delivery_rating          int64
# delivery_cost          float64
# dtype: object

# %%
#One more option to see datatype and null value count in DF
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   delivery_id          25000 non-null  float64
#  1   delivery_partner     25000 non-null  object
#  2   package_type         25000 non-null  object
#  3   vehicle_type         25000 non-null  object
#  4   delivery_mode        25000 non-null  object
#  5   region               25000 non-null  object
#  6   weather_condition    25000 non-null  object
#  7   distance_km          25000 non-null  float64
#  8   package_weight_kg    25000 non-null  float64
#  9   delivery_time_hours  25000 non-null  object
#  10  expected_time_hours  25000 non-null  object
#  11  delayed              25000 non-null  object
#  12  delivery_status      25000 non-null  object
#  13  delivery_rating      25000 non-null  int64
#  14  delivery_cost        25000 non-null  float64
# ...

# %% [markdown]
# ###Statistical Information

# %%
#statistical information about numeric column
df.describe()
# Out:
#         delivery_id   distance_km  package_weight_kg  delivery_rating  \
# count  25000.000000  25000.000000       25000.000000     25000.000000
# mean   12500.500000    150.390436          25.145898         3.666000
# std     7212.732314     86.409745          14.368663         1.149964
# min      250.990000      3.600000           0.670000         1.000000
# 25%     6250.750000     75.900000          12.680000         3.000000
# 50%    12500.500000    151.000000          25.145000         4.000000
# 75%    18750.250000    224.900000          37.660000         5.000000
# max    24750.010000    297.100000          49.520000         5.000000
#
#        delivery_cost
# count   25000.000000
# mean      864.944579
# std       435.712593
# min        95.667400
# 25%       490.800000
# 50%       867.535000
# 75%      1237.910000
# max      1632.720600

# %%
#statistical information about object column
df.describe(include='object')
# Out:
#        delivery_partner   package_type vehicle_type delivery_mode region  \
# count             25000          25000        25000         25000  25000
# unique                9              9            6             4      5
# top          xpressbees  fragile items      ev bike       two day   west
# freq               2826           2848         4218          6302   5095
#
#        weather_condition delivery_time_hours expected_time_hours delayed  \
# count              25000               25000               25000   25000
# unique                 6                   1                   1       2
# top                foggy  1970-01-01 0:00:00  1970-01-01 0:00:00      no
# freq                4219               25000               25000   18331
#
#        delivery_status
# count            25000
# unique               3
# top          delivered
# freq             18331

# %%
df.delayed.value_counts()
# Out:
# delayed
# no     18331
# yes     6669
# Name: count, dtype: int64

# %%
#statistical information about all column
df.describe(include='all')
# Out:
#          delivery_id delivery_partner   package_type vehicle_type  \
# count   25000.000000            25000          25000        25000
# unique           NaN                9              9            6
# top              NaN       xpressbees  fragile items      ev bike
# freq             NaN             2826           2848         4218
# mean    12500.500000              NaN            NaN          NaN
# std      7212.732314              NaN            NaN          NaN
# min       250.990000              NaN            NaN          NaN
# 25%      6250.750000              NaN            NaN          NaN
# 50%     12500.500000              NaN            NaN          NaN
# 75%     18750.250000              NaN            NaN          NaN
# max     24750.010000              NaN            NaN          NaN
#
#        delivery_mode region weather_condition   distance_km  \
# count          25000  25000             25000  25000.000000
# ...

# %% [markdown]
# ### drop unwanted column

# %% [markdown]
# Only 1 type of value under **delivery time hours** and **expected time hours**.
# Is delayed column also connected to above two columns

# %%
df.drop(['delivery_time_hours', 'expected_time_hours', 'delayed'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (25000, 12)

# %% [markdown]
# ### Missing Values and duplicates

# %%
df.isnull().sum()
# Out:
# delivery_id          0
# delivery_partner     0
# package_type         0
# vehicle_type         0
# delivery_mode        0
# region               0
# weather_condition    0
# distance_km          0
# package_weight_kg    0
# delivery_status      0
# delivery_rating      0
# delivery_cost        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #DATASET 2

# %% [markdown]
# ## Analysis

# %%
url = "https://docs.google.com/spreadsheets/d/1SdR6pGLbGdzbPKN-R33RqbsPCX0ZAbzpjMIHs80f_eU/export?format=csv&gid=241453971"
df = pd.read_csv(url)

df.head()
# Out:
#    Order_ID Customer_ID  Order_Date Region Product_Category Customer_Segment  \
# 0         1    CUST3818  2024-08-18  North         Clothing        Corporate
# 1         2    CUST9689  2024-06-19  South           Beauty      Home Office
# 2         3    CUST9147  2024-11-21   West           Sports        Corporate
# 3         4    CUST7938  2024-07-19  North         Clothing         Consumer
# 4         5    CUST5127  2024-10-28  South   Home & Kitchen         Consumer
#
#    Quantity  Unit_Price  Discount_Rate  Revenue     Cost  Profit  \
# 0         5      300.68           0.27  1097.48   768.29  329.19
# 1         9       32.89           0.02   290.09   179.33  110.76
# 2         5      345.61           0.25  1296.04  1022.60  273.44
# 3         1      444.50           0.06   417.83   280.99  136.84
# 4         5       65.13           0.21   257.26   151.90  105.36
#
#   Payment_Method
# 0    Credit Card
# 1     Debit Card
# 2    Credit Card
# 3            UPI
# 4    Credit Card

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          10000 non-null  int64
#  1   Customer_ID       10000 non-null  object
#  2   Order_Date        10000 non-null  object
#  3   Region            10000 non-null  object
#  4   Product_Category  10000 non-null  object
#  5   Customer_Segment  10000 non-null  object
#  6   Quantity          10000 non-null  int64
#  7   Unit_Price        10000 non-null  float64
#  8   Discount_Rate     10000 non-null  float64
#  9   Revenue           10000 non-null  float64
#  10  Cost              10000 non-null  float64
#  11  Profit            10000 non-null  float64
#  12  Payment_Method    10000 non-null  object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 1015.8+ KB

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df.Order_Date.info()
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### Univariate Analysis

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Date', 'Region', 'Product_Category',
#        'Customer_Segment', 'Quantity', 'Unit_Price', 'Discount_Rate',
#        'Revenue', 'Cost', 'Profit', 'Payment_Method'],
#       dtype='object')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Numerical_column =['Quantity','Unit_Price','Discount_Rate','Revenue','Cost','Profit']
Cat_column =['Region','Product_Category','Customer_Segment','Payment_Method']

# %% [markdown]
# #### Numeric Column
#
#
# *   Central Tendency
# *   Spread
# *   Skewness
# *   Outliers
# *   Business Interpretation

# %% [markdown]
# **Central Tendency:** Measure of central value in a given list of values<br><br>
# Numberic: Mean, Median<br>
# Cat: Mode<br>

# %%
df.describe()
# Out:
#           Order_ID                  Order_Date     Quantity    Unit_Price  \
# count  10000.00000                       10000  10000.00000  10000.000000
# mean    5000.50000  2024-06-30 09:16:07.680000      5.51430    255.505222
# min        1.00000         2024-01-01 00:00:00      1.00000     10.000000
# 25%     2500.75000         2024-03-31 00:00:00      3.00000    132.777500
# 50%     5000.50000         2024-06-29 00:00:00      5.00000    254.995000
# 75%     7500.25000         2024-09-28 00:00:00      8.00000    377.892500
# max    10000.00000         2024-12-31 00:00:00     10.00000    499.940000
# std     2886.89568                         NaN      2.86451    140.832874
#
#        Discount_Rate       Revenue          Cost        Profit
# count   10000.000000  10000.000000  10000.000000  10000.000000
# mean        0.150272   1195.241948    776.292180    418.949768
# min         0.000000      8.590000      5.740000      1.970000
# ...

# %%
df.Quantity.mean() #mean
# Out:
# np.float64(5.5143)

# %%
df.Quantity.median() #median
# Out:
# 5.0

# %% [markdown]
# **Spread:** How much the data values are dispersed or scattered.<br><br>
# It does NOT tell you direction.<br>
# It tells you variability.<br>
#
#
#
# *   Range: Difference between Min and Max value  **(Max - min)**
# *   Variance: average of squared difference between all datapoint and mean [ **average((xi − mean)²)** ]
# *   Standard Deviation: Square root of Vairnace [**√Variance**]

# %% [markdown]
# **Range**

# %%
df.Quantity.max()-df.Quantity.min()
# Out:
# 9

# %% [markdown]
# **Variance**

# %%
df.Quantity.var() #variance
# Out:
# 8.205416051605143

# %% [markdown]
# **Standard Deviation**

# %%
df.Quantity.std() #standard deviation
# Out:
# 2.8645097401833253

# %% [markdown]
# **Skewness:**

# %%
df.Quantity.skew()
# Out:
# np.float64(0.011856393249835711)

# %%
sns.histplot(df['Quantity'], kde=True)
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
sns.boxplot(x=df['Quantity'])
# Out:
# <Axes: xlabel='Quantity'>

# %%
for i in Numerical_column:
  print(i,":", df[i].skew())
# Out:
# Quantity : 0.011856393249835711
# Unit_Price : -0.0043722820082742276
# Discount_Rate : 0.0008002503814173447
# Revenue : 1.0085988100498497
# Cost : 1.1401426085493567
# Profit : 1.3108972852975826

# %%
n_cols = 3  # number of columns per row
n_rows = 2

plt.figure(figsize=(18, 5 * n_rows))

for i, col in enumerate(Numerical_column, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.tight_layout()

plt.show()

# %% [markdown]
# | Method          | Use When              | Notes                |
# | --------------- | --------------------- | -------------------- |
# | Log             | Strong right skew     | Most Reliable        |
# | Reflect +Log    | Strong Left skew      | Most Reliable        |
# | Sqrt            | Moderate skew         | Less aggressive      |
# | Box-Cox         | Positive values only  | Statistical approach |
# | Yeo-Johnson     | Zero/negative allowed | More flexible        |
# | Winsorize       | Extreme outliers      | Keeps data size      |
# | Remove Outliers | Data error            | Risky if real        |

# %% [markdown]
# **Question: Do we need to handle Skewness all the times?**

# %% [markdown]
# **Outlier**

# %%
plt.boxplot(df[Numerical_column])
plt.show()
#

# %%
n_cols = 3
n_rows = 2

fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, 5 * n_rows))
axes = axes.flatten()

for i, col in enumerate(Numerical_column):
    sns.boxplot(x=df[col], ax=axes[i])
    axes[i].set_title(f'Boxplot of {col}')

# Remove extra empty plots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Categorical
#
# *  Value Counts - Bar Chart
# *  Percentage distribution

# %%
for i in Cat_column:
  print(df[i].value_counts())
  print("---"*10,"\n\n")
# Out:
# Region
# North    2548
# East     2506
# West     2486
# South    2460
# Name: count, dtype: int64
# ------------------------------
#
#
# Product_Category
# Clothing          2008
# Home & Kitchen    2008
# Sports            1997
# Beauty            1996
# Electronics       1991
# Name: count, dtype: int64
# ------------------------------
#
#
# Customer_Segment
# Home Office    3389
# Corporate      3316
# Consumer       3295
# Name: count, dtype: int64
# ------------------------------
#
#
# Payment_Method
# Debit Card          2074
# Cash on Delivery    2017
# UPI                 2011
# Credit Card         1963
# Net Banking         1935
# Name: count, dtype: int64
# ------------------------------

# %%
sns.countplot(y=df['Region'],)
# Out:
# <Axes: xlabel='count', ylabel='Region'>

# %%
for i in Cat_column:
  print(df[i].value_counts(normalize=True) * 100)
  print("---"*10,"\n\n")
# Out:
# Region
# North    25.48
# East     25.06
# West     24.86
# South    24.60
# Name: proportion, dtype: float64
# ------------------------------
#
#
# Product_Category
# Clothing          20.08
# Home & Kitchen    20.08
# Sports            19.97
# Beauty            19.96
# Electronics       19.91
# Name: proportion, dtype: float64
# ------------------------------
#
#
# Customer_Segment
# Home Office    33.89
# Corporate      33.16
# Consumer       32.95
# Name: proportion, dtype: float64
# ------------------------------
#
#
# Payment_Method
# Debit Card          20.74
# Cash on Delivery    20.17
# UPI                 20.11
# Credit Card         19.63
# Net Banking         19.35
# Name: proportion, dtype: float64
# ------------------------------

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **Numerical vs Numerical**

# %%
Numerical_column
# Out:
# ['Quantity', 'Unit_Price', 'Discount_Rate', 'Revenue', 'Cost', 'Profit']

# %% [markdown]
# **ScatterPlot**

# %%
sns.scatterplot(x='Revenue', y='Profit', data=df)
plt.title("Revenue vs Profit")
plt.show()

# %%
sns.scatterplot(x='Cost', y='Profit', data=df)
plt.title("Revenue vs Profit")
plt.show()

# %%
sns.scatterplot(x='Discount_Rate', y='Profit', data=df)
plt.title("Revenue vs Profit")
plt.show()

# %% [markdown]
# **What to Analyze:**
#
# - Linear pattern?
#
# - Cluster pattern?
#
# - Outliers pulling trend?

# %% [markdown]
# **Correlation Heatmap**

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# **What to Analyze:**
#
# * Strong positive (> 0.7)
# * Strong negative (< -0.7)
# * Multicollinearity

# %% [markdown]
# #### **Numerical vs Categorical**

# %% [markdown]
# **Box Plot**

# %%
sns.boxplot(x='Region', y='Profit', data=df)
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='Product_Category', y='Cost', data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Analyze:**
#
# * Median differences
# * Spread differences
# * Outlier concentration
# * Skew variation

# %% [markdown]
# **Barplot**

# %%
sns.barplot(x='Region', y='Profit', data=df)
plt.show()

# %%
sns.barplot(x='Product_Category', y='Profit', data=df)
plt.show()

# %% [markdown]
# #### **Categorical vs Categorical**

# %% [markdown]
# Cross tab

# %%
pd.crosstab(df['Region'], df['Payment_Method'])
# Out:
# Payment_Method  Cash on Delivery  Credit Card  Debit Card  Net Banking  UPI
# Region
# East                         508          516         523          457  502
# North                        536          507         504          476  525
# South                        491          475         537          475  482
# West                         482          465         510          527  502

# %% [markdown]
# Crosstab with Normalized value

# %%
pd.crosstab(df['Region'], df['Payment_Method'], normalize='index') * 100
# Out:
# Payment_Method  Cash on Delivery  Credit Card  Debit Card  Net Banking  \
# Region
# East                   20.271349    20.590583   20.869912    18.236233
# North                  21.036107    19.897959   19.780220    18.681319
# South                  19.959350    19.308943   21.829268    19.308943
# West                   19.388576    18.704747   20.514883    21.198713
#
# Payment_Method        UPI
# Region
# East            20.031923
# North           20.604396
# South           19.593496
# West            20.193081

# %% [markdown]
# **Stacked Bar Chart**

# %%
ct = pd.crosstab(df['Region'], df['Payment_Method'], normalize='index')

ct.plot(kind='bar', stacked=True, figsize=(8,6))
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# ***Strong Comparison Summary*** <br><br>
#
# | Type       | Best Chart  | What to Observe               |
# | ---------- | ----------- | ----------------------------- |
# | Num vs Num | Scatter     | Linearity, clusters, outliers |
# | Num vs Cat | Boxplot     | Median, spread difference     |
# | Cat vs Cat | Stacked bar | Proportion comparison         |

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# **Pairplot**

# %%
sns.pairplot(df[['Quantity','Unit_Price','Revenue','Profit']])
plt.show()

# %%
df.groupby(['Region','Customer_Segment'])['Profit'].mean().unstack().plot(kind='bar')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['Quantity'],
           df['Unit_Price'],
           df['Profit'])

ax.set_xlabel('Quantity')
ax.set_ylabel('Unit_Price')
ax.set_zlabel('Profit')

plt.show()

# %% [markdown]
# ## **WHEN TO USE WHAT**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
created by ankit sharma
